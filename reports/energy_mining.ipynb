# %% [markdown]
# # Energy Mining

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd

# %%
df = pd.read_csv('../selected_data.csv')
df.head()
# Out:
#   Country Code                  Category Name  \
# 0          ALB  agriculture_rural_development
# 1          ARG  agriculture_rural_development
# 2          ARM  agriculture_rural_development
# 3          AUS  agriculture_rural_development
# 4          AUT  agriculture_rural_development
#
#                              Indicator Name    1991    1992    1993    1994  \
# 0  Rural population (% of total population)  63.300  62.751  62.201  61.646
# 1  Rural population (% of total population)  12.672  12.458  12.248  12.040
# 2  Rural population (% of total population)  32.850  33.122  33.394  33.668
# 3  Rural population (% of total population)  14.597  14.715  14.843  14.972
# 4  Rural population (% of total population)  37.311  37.583  37.856  38.130
#
#      1995    1996    1997  ...    2013    2014    2015    2016    2017  \
# 0  61.089  60.527  59.965  ...  44.613  43.577  42.566  41.579  40.617
# 1  11.836  11.634  11.436  ...   8.751   8.623   8.497   8.373   8.251
# 2  33.943  34.219  34.496  ...  36.836  36.888  36.915  36.918  36.897
# 3  15.102  15.233  15.364  ...  14.498  14.398  14.299  14.200  14.096
# 4  38.404  38.680  38.955  ...  42.664  42.474  42.285  42.095  41.906
#
#      2018    2019    2020    2021  Country Name
# 0  39.681  38.771  37.888  37.031       Albania
# 1   8.130   8.009   7.889   7.771     Argentina
# 2  36.851  36.781  36.687  36.569       Armenia
# 3  13.988  13.876  13.759  13.638     Australia
# 4  41.703  41.485  41.252  41.005       Austria
#
# [5 rows x 35 columns]

# %%
category_name = 'energy_mining'

# %%
df = df[df['Category Name'] == category_name]
df.head()
# Out:
#      Country Code  Category Name  \
# 4656          ALB  energy_mining
# 4657          ARG  energy_mining
# 4658          ARM  energy_mining
# 4659          AUS  energy_mining
# 4660          AUT  energy_mining
#
#                                         Indicator Name          1991  \
# 4656  Adjusted savings: energy depletion (current US$)  2.489885e+07
# 4657  Adjusted savings: energy depletion (current US$)  1.553942e+09
# 4658  Adjusted savings: energy depletion (current US$)  0.000000e+00
# 4659  Adjusted savings: energy depletion (current US$)  2.089966e+09
# 4660  Adjusted savings: energy depletion (current US$)  7.372741e+07
#
#               1992          1993          1994          1995          1996  \
# 4656  1.517140e+07  1.627050e+07  1.500357e+07  1.349140e+07  1.737295e+07
# 4657  1.869723e+09  1.946268e+09  2.070254e+09  2.593953e+09  3.444839e+09
# 4658  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 4659  1.973280e+09  1.977670e+09  1.624373e+09  2.010816e+09  2.220965e+09
# 4660  6.650786e+07  7.177202e+07  6.018650e+07  7.626562e+07  9.062041e+07
#
#               1997  ...          2013          2014          2015  \
# 4656  1.027321e+07  ...  2.610624e+08  2.947728e+08  1.162949e+08
# 4657  3.374717e+09  ...  1.289048e+10  1.139862e+10  4.610440e+09
# 4658  0.000000e+00  ...  0.000000e+00  0.000000e+00  0.000000e+00
# 4659  2.007899e+09  ...  9.644762e+09  1.079717e+10  7.509900e+09
# 4660  7.972061e+07  ...  4.434619e+08  4.077298e+08  1.889476e+08
#
#               2016          2017          2018          2019          2020  \
# 4656  6.881296e+07  9.253487e+07  1.369031e+08  1.396515e+08  5.183105e+07
# 4657  3.098046e+09  4.240724e+09  7.274093e+09  6.609774e+09  3.025507e+09
# 4658  0.000000e+00  4.884879e-01  8.776758e-01  6.426357e-01  5.433923e-01
# 4659  6.967690e+09  9.812513e+09  1.577971e+10  1.772756e+10  1.447879e+10
# 4660  1.222826e+08  1.723861e+08  2.508391e+08  1.936523e+08  8.479964e+07
#
#               2021  Country Name
# 4656  1.075656e+08       Albania
# 4657  7.613365e+09     Argentina
# 4658  1.105281e+00       Armenia
# 4659  2.504931e+10     Australia
# 4660  2.596251e+08       Austria
#
# [5 rows x 35 columns]

# %%
df['Indicator Name'].unique()
# Out:
# array(['Adjusted savings: energy depletion (current US$)',
#        'Adjusted savings: mineral depletion (current US$)'], dtype=object)

# %% [markdown]
# ## Preprocess

# %%
import sys
sys.path.append('../')

# %%
from utlis.data_preprocess import fill_missing_with_mean, min_max_scaling_by_specific_category

df = fill_missing_with_mean(df)
df = min_max_scaling_by_specific_category(df)
df.head()
# Out:
#      Country Code  Category Name  \
# 4656          ALB  energy_mining
# 4657          ARG  energy_mining
# 4658          ARM  energy_mining
# 4659          AUS  energy_mining
# 4660          AUT  energy_mining
#
#                                         Indicator Name      1991      1992  \
# 4656  Adjusted savings: energy depletion (current US$)  0.000786  0.000417
# 4657  Adjusted savings: energy depletion (current US$)  0.049085  0.051374
# 4658  Adjusted savings: energy depletion (current US$)  0.000000  0.000000
# 4659  Adjusted savings: energy depletion (current US$)  0.066016  0.054219
# 4660  Adjusted savings: energy depletion (current US$)  0.002329  0.001827
#
#           1993      1994      1995      1996      1997  ...      2013  \
# 4656  0.000429  0.000456  0.000450  0.000382  0.000261  ...  0.001717
# 4657  0.051298  0.062911  0.086432  0.075764  0.085662  ...  0.084798
# 4658  0.000000  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 4659  0.052125  0.049361  0.067002  0.048847  0.050967  ...  0.063446
# 4660  0.001892  0.001829  0.002541  0.001993  0.002024  ...  0.002917
#
#           2014      2015      2016          2017          2018          2019  \
# 4656  0.002161  0.001806  0.001314  1.247559e-03  1.112346e-03  1.307344e-03
# 4657  0.083550  0.071610  0.059164  5.717360e-02  5.910246e-02  6.187720e-02
# 4658  0.000000  0.000000  0.000000  6.585812e-12  7.131171e-12  6.016015e-12
# 4659  0.079141  0.116645  0.133063  1.322927e-01  1.282111e-01  1.659560e-01
# 4660  0.002989  0.002935  0.002335  2.324116e-03  2.038084e-03  1.812870e-03
#
#               2020          2021  Country Name
# 4656  9.831494e-04  6.035826e-04       Albania
# 4657  5.738886e-02  4.272085e-02     Argentina
# 4658  1.030725e-11  6.202061e-12       Armenia
# 4659  2.746388e-01  1.405591e-01     Australia
# 4660  1.608509e-03  1.456833e-03       Austria
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Arithmetic mean

# %%
plot_mean_title = f'Mean of {category_name}'

# %%
df_mean = df[['Country Name','Indicator Name']].copy()
df_mean['Mean'] = df.loc[:,"1991":"2021"].mean(axis=1)
df_mean.head()
# Out:
#      Country Name                                    Indicator Name  \
# 4656      Albania  Adjusted savings: energy depletion (current US$)
# 4657    Argentina  Adjusted savings: energy depletion (current US$)
# 4658      Armenia  Adjusted savings: energy depletion (current US$)
# 4659    Australia  Adjusted savings: energy depletion (current US$)
# 4660      Austria  Adjusted savings: energy depletion (current US$)
#
#               Mean
# 4656  6.881325e-04
# 4657  7.129855e-02
# 4658  1.169107e-12
# 4659  8.196908e-02
# 4660  2.229490e-03

# %% [markdown]
# ### Dendogram

# %%
from utlis.visualisation import plot_dendogram

plot_dendogram(df_mean, plot_mean_title, 'Mean')
# Out:
# 2024-05-26 18:44:33.773140: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### KMeans

# %%
from utlis.kmeans import calculate_kmeans

k_means_outcome, cluster_centers = calculate_kmeans(df_mean, plot_mean_title, 'Mean')

# %%
from utlis.visualisation import plot_tsne

plot_tsne(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_mean_title)

# %%
from utlis.visualisation import plot_umap

plot_umap(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_mean_title)
# Out:
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from utlis.visualisation import plot_pca

plot_pca(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], k_means_outcome.columns.values[:-1], plot_mean_title)

# %%
from utlis.visualisation import plot_centroid

plot_centroid(cluster_centers, k_means_outcome, plot_mean_title)

# %%
from utlis.map_handler import plot_map

plot_map(k_means_outcome['Cluster'], plot_mean_title)
# Out:
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Last available year - 2021

# %%
plot_last_year_title = f'{category_name} for 2021'

# %%
df_2021 = df[['Country Name','Indicator Name', '2021']].copy()
df_2021.head()
# Out:
#      Country Name                                    Indicator Name  \
# 4656      Albania  Adjusted savings: energy depletion (current US$)
# 4657    Argentina  Adjusted savings: energy depletion (current US$)
# 4658      Armenia  Adjusted savings: energy depletion (current US$)
# 4659    Australia  Adjusted savings: energy depletion (current US$)
# 4660      Austria  Adjusted savings: energy depletion (current US$)
#
#               2021
# 4656  6.035826e-04
# 4657  4.272085e-02
# 4658  6.202061e-12
# 4659  1.405591e-01
# 4660  1.456833e-03

# %% [markdown]
# ### Dendogram

# %%
from utlis.visualisation import plot_dendogram

plot_dendogram(df_2021, plot_last_year_title, '2021')

# %% [markdown]
# ### KMeans

# %%
from utlis.kmeans import calculate_kmeans

k_means_outcome, cluster_centers = calculate_kmeans(df_2021, plot_last_year_title, '2021')

# %%
from utlis.visualisation import plot_tsne

plot_tsne(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_last_year_title)

# %%
from utlis.visualisation import plot_umap

plot_umap(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_last_year_title)
# Out:
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from utlis.visualisation import plot_pca

plot_pca(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], k_means_outcome.columns.values[:-1], plot_last_year_title)

# %%
from utlis.visualisation import plot_centroid

plot_centroid(cluster_centers, k_means_outcome, plot_last_year_title)

# %%
from utlis.map_handler import plot_map

plot_map(k_means_outcome['Cluster'], plot_last_year_title)
# Out:
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Dynamic Time Warping

# %%
from utlis.dtw import get_indicator_dtw_matrix, plot_time_series_compare_matrix

for indicator in df['Indicator Name'].unique():
    indicator_compare_dataframe = get_indicator_dtw_matrix(df[df['Indicator Name'] == indicator])
    plot_time_series_compare_matrix(indicator_compare_dataframe, indicator_compare_dataframe.columns, indicator, 20)
