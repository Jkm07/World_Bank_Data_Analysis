# %% [markdown]
# # Urban development

# %% [markdown]
# ## Loading Data

# %%
import pandas as pd

# %%
df = pd.read_csv('../selected_data.csv')
df.head()
# Out:
#   Country Code                  Category Name  \
# 0          ALB  agriculture_rural_development
# 1          ARG  agriculture_rural_development
# 2          ARM  agriculture_rural_development
# 3          AUS  agriculture_rural_development
# 4          AUT  agriculture_rural_development
#
#                              Indicator Name    1991    1992    1993    1994  \
# 0  Rural population (% of total population)  63.300  62.751  62.201  61.646
# 1  Rural population (% of total population)  12.672  12.458  12.248  12.040
# 2  Rural population (% of total population)  32.850  33.122  33.394  33.668
# 3  Rural population (% of total population)  14.597  14.715  14.843  14.972
# 4  Rural population (% of total population)  37.311  37.583  37.856  38.130
#
#      1995    1996    1997  ...    2013    2014    2015    2016    2017  \
# 0  61.089  60.527  59.965  ...  44.613  43.577  42.566  41.579  40.617
# 1  11.836  11.634  11.436  ...   8.751   8.623   8.497   8.373   8.251
# 2  33.943  34.219  34.496  ...  36.836  36.888  36.915  36.918  36.897
# 3  15.102  15.233  15.364  ...  14.498  14.398  14.299  14.200  14.096
# 4  38.404  38.680  38.955  ...  42.664  42.474  42.285  42.095  41.906
#
#      2018    2019    2020    2021  Country Name
# 0  39.681  38.771  37.888  37.031       Albania
# 1   8.130   8.009   7.889   7.771     Argentina
# 2  36.851  36.781  36.687  36.569       Armenia
# 3  13.988  13.876  13.759  13.638     Australia
# 4  41.703  41.485  41.252  41.005       Austria
#
# [5 rows x 35 columns]

# %%
category_name = 'urban_developmen'

# %%
df = df[df['Category Name'] == category_name]
df.head()
# Out:
#       Country Code     Category Name  \
# 12222          ALB  urban_developmen
# 12223          ARG  urban_developmen
# 12224          ARM  urban_developmen
# 12225          AUS  urban_developmen
# 12226          AUT  urban_developmen
#
#                                  Indicator Name    1991    1992    1993  \
# 12222  Urban population (% of total population)  36.700  37.249  37.799
# 12223  Urban population (% of total population)  87.328  87.542  87.752
# 12224  Urban population (% of total population)  67.150  66.878  66.606
# 12225  Urban population (% of total population)  85.403  85.285  85.157
# 12226  Urban population (% of total population)  62.689  62.417  62.144
#
#          1994    1995    1996    1997  ...    2013    2014    2015    2016  \
# 12222  38.354  38.911  39.473  40.035  ...  55.387  56.423  57.434  58.421
# 12223  87.960  88.164  88.366  88.564  ...  91.249  91.377  91.503  91.627
# 12224  66.332  66.057  65.781  65.504  ...  63.164  63.112  63.085  63.082
# 12225  85.028  84.898  84.767  84.636  ...  85.502  85.602  85.701  85.800
# 12226  61.870  61.596  61.320  61.045  ...  57.336  57.526  57.715  57.905
#
#          2017    2018    2019    2020    2021  Country Name
# 12222  59.383  60.319  61.229  62.112  62.969       Albania
# 12223  91.749  91.870  91.991  92.111  92.229     Argentina
# 12224  63.103  63.149  63.219  63.313  63.431       Armenia
# 12225  85.904  86.012  86.124  86.241  86.362     Australia
# 12226  58.094  58.297  58.515  58.748  58.995       Austria
#
# [5 rows x 35 columns]

# %%
df['Indicator Name'].unique()
# Out:
# array(['Urban population (% of total population)',
#        'Population density (people per sq. km of land area)'],
#       dtype=object)

# %% [markdown]
# ## Preprocess

# %%
import sys
sys.path.append('../')

# %%
from utlis.data_preprocess import fill_missing_with_mean, min_max_scaling_by_specific_category

df = fill_missing_with_mean(df)
df = min_max_scaling_by_specific_category(df)
df.head()
# Out:
#       Country Code     Category Name  \
# 12222          ALB  urban_developmen
# 12223          ARG  urban_developmen
# 12224          ARM  urban_developmen
# 12225          AUS  urban_developmen
# 12226          AUT  urban_developmen
#
#                                  Indicator Name      1991      1992      1993  \
# 12222  Urban population (% of total population)  0.323320  0.327881  0.332443
# 12223  Urban population (% of total population)  0.864536  0.866564  0.868551
# 12224  Urban population (% of total population)  0.648832  0.645234  0.641607
# 12225  Urban population (% of total population)  0.843957  0.842389  0.840701
# 12226  Urban population (% of total population)  0.601144  0.597453  0.593719
#
#            1994      1995      1996      1997  ...      2013      2014  \
# 12222  0.337040  0.341635  0.346276  0.350902  ...  0.496001  0.506064
# 12223  0.870518  0.872442  0.874347  0.876210  ...  0.901139  0.902260
# 12224  0.637924  0.634192  0.630416  0.626594  ...  0.583859  0.581882
# 12225  0.838987  0.837244  0.835475  0.833691  ...  0.836214  0.836802
# 12226  0.589938  0.586115  0.582235  0.578327  ...  0.518019  0.518566
#
#            2015      2016      2017      2018      2019      2020      2021  \
# 12222  0.515866  0.525419  0.534710  0.543729  0.552474  0.560933  0.569116
# 12223  0.903358  0.904431  0.905480  0.906517  0.907554  0.908578  0.909579
# 12224  0.580139  0.578619  0.577325  0.576269  0.575444  0.574851  0.574492
# 12225  0.837367  0.837922  0.838523  0.839159  0.839832  0.840553  0.841312
# 12226  0.519062  0.519529  0.519944  0.520479  0.521146  0.521949  0.522876
#
#        Country Name
# 12222       Albania
# 12223     Argentina
# 12224       Armenia
# 12225     Australia
# 12226       Austria
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Arithmetic mean

# %%
plot_mean_title = f'Mean of {category_name}'

# %%
df_mean = df[['Country Name','Indicator Name']].copy()
df_mean['Mean'] = df.loc[:,"1991":"2021"].mean(axis=1)
df_mean.head()
# Out:
#       Country Name                            Indicator Name      Mean
# 12222      Albania  Urban population (% of total population)  0.431669
# 12223    Argentina  Urban population (% of total population)  0.889913
# 12224      Armenia  Urban population (% of total population)  0.603474
# 12225    Australia  Urban population (% of total population)  0.834957
# 12226      Austria  Urban population (% of total population)  0.548031

# %% [markdown]
# ### Dendogram

# %%
from utlis.visualisation import plot_dendogram

plot_dendogram(df_mean, plot_mean_title, 'Mean')
# Out:
# 2024-05-27 09:07:21.718470: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### KMeans

# %%
from utlis.kmeans import calculate_kmeans

k_means_outcome, cluster_centers = calculate_kmeans(df_mean, plot_mean_title, 'Mean')

# %%
from utlis.visualisation import plot_tsne

plot_tsne(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_mean_title)

# %%
from utlis.visualisation import plot_umap

plot_umap(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_mean_title)
# Out:
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from utlis.visualisation import plot_pca

plot_pca(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], k_means_outcome.columns.values[:-1], plot_mean_title)

# %%
from utlis.visualisation import plot_centroid

plot_centroid(cluster_centers, k_means_outcome, plot_mean_title)
# Out:
# Population_0 -> Population density (people per sq. km of land area)
# Urban popu_1 -> Urban population (% of total population)

# %%
from utlis.map_handler import plot_map

plot_map(k_means_outcome['Cluster'], plot_mean_title)
# Out:
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Last available year - 2021

# %%
plot_last_year_title = f'{category_name} for 2021'

# %%
df_2021 = df[['Country Name','Indicator Name', '2021']].copy()
df_2021.head()
# Out:
#       Country Name                            Indicator Name      2021
# 12222      Albania  Urban population (% of total population)  0.569116
# 12223    Argentina  Urban population (% of total population)  0.909579
# 12224      Armenia  Urban population (% of total population)  0.574492
# 12225    Australia  Urban population (% of total population)  0.841312
# 12226      Austria  Urban population (% of total population)  0.522876

# %% [markdown]
# ### Dendogram

# %%
from utlis.visualisation import plot_dendogram

plot_dendogram(df_2021, plot_last_year_title, '2021')

# %% [markdown]
# ### KMeans

# %%
from utlis.kmeans import calculate_kmeans

k_means_outcome, cluster_centers = calculate_kmeans(df_2021, plot_last_year_title, '2021')

# %%
from utlis.visualisation import plot_tsne

plot_tsne(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_last_year_title)

# %%
from utlis.visualisation import plot_umap

plot_umap(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_last_year_title)
# Out:
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from utlis.visualisation import plot_pca

plot_pca(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], k_means_outcome.columns.values[:-1], plot_last_year_title)

# %%
from utlis.visualisation import plot_centroid

plot_centroid(cluster_centers, k_means_outcome, plot_last_year_title)
# Out:
# Population_0 -> Population density (people per sq. km of land area)
# Urban popu_1 -> Urban population (% of total population)

# %%
from utlis.map_handler import plot_map

plot_map(k_means_outcome['Cluster'], plot_last_year_title)
# Out:
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Dynamic Time Warping

# %%
from utlis.dtw import get_indicator_dtw_matrix, plot_time_series_compare_matrix

for indicator in df['Indicator Name'].unique():
    indicator_compare_dataframe = get_indicator_dtw_matrix(df[df['Indicator Name'] == indicator])
    plot_time_series_compare_matrix(indicator_compare_dataframe, indicator_compare_dataframe.columns, indicator, 20)

# %% [markdown]
# ## Autoencoder

# %%
from utlis.autoencoder import VAE, prepare_data, get_enoder_cluster, train
epochs = 1000

model = VAE(len(df['Indicator Name'].unique()))
X, Y = prepare_data(df)
train(model, X, epochs)
result = get_enoder_cluster(model, X, Y)
plot_map(result, "Autoencoder")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch: 1, Test set ELBO: -12.538317680358887
# Epoch: 26, Test set ELBO: -6.893486499786377
# Epoch: 51, Test set ELBO: -4.64605712890625
# Epoch: 76, Test set ELBO: -2.3523671627044678
# Epoch: 101, Test set ELBO: -2.0998218059539795
# Epoch: 126, Test set ELBO: -2.0448131561279297
# Epoch: 151, Test set ELBO: -1.9728401899337769
# Epoch: 176, Test set ELBO: -1.9516204595565796
# Epoch: 201, Test set ELBO: -1.9090205430984497
# Epoch: 226, Test set ELBO: -1.896655797958374
# Epoch: 251, Test set ELBO: -1.8916802406311035
# Epoch: 276, Test set ELBO: -1.8877553939819336
# Epoch: 301, Test set ELBO: -1.8813724517822266
# Epoch: 326, Test set ELBO: -1.882993459701538
# Epoch: 351, Test set ELBO: -1.8811166286468506
# Epoch: 376, Test set ELBO: -1.8802828788757324
# Epoch: 401, Test set ELBO: -1.883622169494629
# Epoch: 426, Test set ELBO: -1.8703094720840454
# Epoch: 451, Test set ELBO: -1.865114688873291
# Epoch: 476, Test set ELBO: -1.863964557647705
# Epoch: 501, Test set ELBO: -1.8636857271194458
# Epoch: 526, Test set ELBO: -1.8625105619430542
# Epoch: 551, Test set ELBO: -1.8560354709625244
# Epoch: 576, Test set ELBO: -1.8554258346557617
# Epoch: 601, Test set ELBO: -1.8499057292938232
# Epoch: 626, Test set ELBO: -1.8506916761398315
# Epoch: 651, Test set ELBO: -1.8460911512374878
# Epoch: 676, Test set ELBO: -1.853629469871521
# Epoch: 701, Test set ELBO: -1.8490382432937622
# Epoch: 726, Test set ELBO: -1.8494913578033447
# Epoch: 751, Test set ELBO: -1.847933292388916
# Epoch: 776, Test set ELBO: -1.8422397375106812
# Epoch: 801, Test set ELBO: -1.8396114110946655
# Epoch: 826, Test set ELBO: -1.839936375617981
# Epoch: 851, Test set ELBO: -1.8381760120391846
# Epoch: 876, Test set ELBO: -1.8361810445785522
# Epoch: 901, Test set ELBO: -1.8332321643829346
# Epoch: 926, Test set ELBO: -1.8364920616149902
# Epoch: 951, Test set ELBO: -1.82826828956604
# Epoch: 976, Test set ELBO: -1.8363440036773682
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
