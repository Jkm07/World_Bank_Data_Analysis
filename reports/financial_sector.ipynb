# %% [markdown]
# # Financial sector

# %%
import pandas as pd

# %%
df = pd.read_csv('../selected_data.csv')
df.head()
# Out:
#   Country Code                  Category Name  \
# 0          ALB  agriculture_rural_development
# 1          ARG  agriculture_rural_development
# 2          ARM  agriculture_rural_development
# 3          AUS  agriculture_rural_development
# 4          AUT  agriculture_rural_development
#
#                              Indicator Name    1991    1992    1993    1994  \
# 0  Rural population (% of total population)  63.300  62.751  62.201  61.646
# 1  Rural population (% of total population)  12.672  12.458  12.248  12.040
# 2  Rural population (% of total population)  32.850  33.122  33.394  33.668
# 3  Rural population (% of total population)  14.597  14.715  14.843  14.972
# 4  Rural population (% of total population)  37.311  37.583  37.856  38.130
#
#      1995    1996    1997  ...    2013    2014    2015    2016    2017  \
# 0  61.089  60.527  59.965  ...  44.613  43.577  42.566  41.579  40.617
# 1  11.836  11.634  11.436  ...   8.751   8.623   8.497   8.373   8.251
# 2  33.943  34.219  34.496  ...  36.836  36.888  36.915  36.918  36.897
# 3  15.102  15.233  15.364  ...  14.498  14.398  14.299  14.200  14.096
# 4  38.404  38.680  38.955  ...  42.664  42.474  42.285  42.095  41.906
#
#      2018    2019    2020    2021  Country Name
# 0  39.681  38.771  37.888  37.031       Albania
# 1   8.130   8.009   7.889   7.771     Argentina
# 2  36.851  36.781  36.687  36.569       Armenia
# 3  13.988  13.876  13.759  13.638     Australia
# 4  41.703  41.485  41.252  41.005       Austria
#
# [5 rows x 35 columns]

# %%
category_name = 'financial_sector'

# %%
df = df[df['Category Name'] == category_name]
df.head()
# Out:
#      Country Code     Category Name Indicator Name     1991      1992  \
# 5335          ALB  financial_sector  Net migration -56599.0  -59634.0
# 5336          ARG  financial_sector  Net migration  -8569.0  -13201.0
# 5337          ARM  financial_sector  Net migration   5419.0 -196273.0
# 5338          AUS  financial_sector  Net migration  68867.0   34149.0
# 5339          AUT  financial_sector  Net migration  77195.0   71035.0
#
#           1993      1994     1995     1996     1997  ...      2013      2014  \
# 5335  -61925.0  -63700.0 -65106.0 -65800.0 -65975.0  ...  -16845.0  -14265.0
# 5336  -16383.0  -18725.0 -19736.0 -20396.0 -20588.0  ...    5369.0    5801.0
# 5337 -126968.0 -112567.0 -50217.0 -51023.0 -51638.0  ...  -28257.0  -27763.0
# 5338   23422.0   53636.0  79727.0  82770.0  67260.0  ...  214564.0  198120.0
# 5339   33610.0    2844.0   1447.0   3969.0   1459.0  ...   56494.0   74263.0
#
#           2015      2016      2017      2018      2019      2020      2021  \
# 5335  -12240.0  -10887.0   -9768.0   -9106.0   -8889.0   -9117.0  -10612.0
# 5336    5522.0    5215.0    4926.0    4690.0    4478.0    2344.0    2344.0
# 5337  -27283.0  -26804.0  -26326.0  -25835.0  -25363.0  -12825.0  -12825.0
# 5338  209466.0  242184.0  244875.0  220307.0  235860.0  117929.0  117929.0
# 5339  115125.0   66282.0   45573.0   35404.0   41105.0   20314.0   20314.0
#
#       Country Name
# 5335       Albania
# 5336     Argentina
# 5337       Armenia
# 5338     Australia
# 5339       Austria
#
# [5 rows x 35 columns]

# %%
df['Indicator Name'].unique()
# Out:
# array(['Net migration',
#        'GDP deflator: linked series (base year varies by country)',
#        'Inflation, GDP deflator: linked series (annual %)'], dtype=object)

# %% [markdown]
# ## Preprocess

# %%
import sys
sys.path.append('../')

# %%
from utlis.data_preprocess import fill_missing_with_mean, min_max_scaling_by_specific_category

df = fill_missing_with_mean(df)
df = min_max_scaling_by_specific_category(df)
df.head()
# Out:
#      Country Code     Category Name Indicator Name      1991      1992  \
# 5335          ALB  financial_sector  Net migration  0.301234  0.401958
# 5336          ARG  financial_sector  Net migration  0.321877  0.416759
# 5337          ARM  financial_sector  Net migration  0.327889  0.358403
# 5338          AUS  financial_sector  Net migration  0.355158  0.431852
# 5339          AUT  financial_sector  Net migration  0.358738  0.443610
#
#           1993      1994      1995      1996      1997  ...      2013  \
# 5335  0.274981  0.196130  0.243267  0.209894  0.183773  ...  0.585491
# 5336  0.293182  0.215459  0.262954  0.229418  0.202940  ...  0.592374
# 5337  0.248985  0.175127  0.249728  0.216248  0.189827  ...  0.581955
# 5338  0.309091  0.246559  0.306114  0.273780  0.240038  ...  0.657198
# 5339  0.313162  0.224729  0.272146  0.239895  0.212250  ...  0.608217
#
#           2014      2015      2016      2017      2018      2019      2020  \
# 5335  0.615310  0.636392  0.609534  0.530048  0.518045  0.500213  0.597451
# 5336  0.621411  0.641625  0.613840  0.535025  0.523541  0.505936  0.604190
# 5337  0.611206  0.631960  0.605278  0.524439  0.511381  0.493160  0.595271
# 5338  0.679887  0.701715  0.677204  0.616303  0.609430  0.605001  0.672147
# 5339  0.642228  0.673918  0.630169  0.548793  0.535775  0.521618  0.614755
#
#           2021  Country Name
# 5335  0.446074       Albania
# 5336  0.458616     Argentina
# 5337  0.443931       Armenia
# 5338  0.570511     Australia
# 5339  0.476012       Austria
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Arithmetic mean

# %%
plot_mean_title = f'Mean of {category_name}'

# %%
df_mean = df[['Country Name','Indicator Name']].copy()
df_mean['Mean'] = df.loc[:,"1991":"2021"].mean(axis=1)
df_mean.head()
# Out:
#      Country Name Indicator Name      Mean
# 5335      Albania  Net migration  0.380121
# 5336    Argentina  Net migration  0.394245
# 5337      Armenia  Net migration  0.380395
# 5338    Australia  Net migration  0.467731
# 5339      Austria  Net migration  0.415101

# %% [markdown]
# ### Dendogram

# %%
from utlis.visualisation import plot_dendogram

plot_dendogram(df_mean, plot_mean_title, 'Mean')
# Out:
# 2024-05-27 07:36:01.145702: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.11/dist-packages/dask/dataframe/__init__.py:31: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### KMeans

# %%
from utlis.kmeans import calculate_kmeans

k_means_outcome, cluster_centers = calculate_kmeans(df_mean, plot_mean_title, 'Mean')

# %%
from utlis.visualisation import plot_tsne

plot_tsne(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_mean_title)

# %%
from utlis.visualisation import plot_umap

plot_umap(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_mean_title)
# Out:
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from utlis.visualisation import plot_pca

plot_pca(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], k_means_outcome.columns.values[:-1], plot_mean_title)

# %%
from utlis.visualisation import plot_centroid

plot_centroid(cluster_centers, k_means_outcome, plot_mean_title)
# Out:
# GDP deflat_0 -> GDP deflator: linked series (base year varies by country)
# Inflation,_1 -> Inflation, GDP deflator: linked series (annual %)
# Net migrat_2 -> Net migration

# %%
from utlis.map_handler import plot_map

plot_map(k_means_outcome['Cluster'], plot_mean_title)
# Out:
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Last available year - 2021

# %%
plot_last_year_title = f'{category_name} for 2021'

# %%
df_2021 = df[['Country Name','Indicator Name', '2021']].copy()
df_2021.head()
# Out:
#      Country Name Indicator Name      2021
# 5335      Albania  Net migration  0.446074
# 5336    Argentina  Net migration  0.458616
# 5337      Armenia  Net migration  0.443931
# 5338    Australia  Net migration  0.570511
# 5339      Austria  Net migration  0.476012

# %% [markdown]
# ### Dendogram

# %%
from utlis.visualisation import plot_dendogram

plot_dendogram(df_2021, plot_last_year_title, '2021')

# %% [markdown]
# ### KMeans

# %%
from utlis.kmeans import calculate_kmeans

k_means_outcome, cluster_centers = calculate_kmeans(df_2021, plot_last_year_title, '2021')

# %%
from utlis.visualisation import plot_tsne

plot_tsne(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_last_year_title)

# %%
from utlis.visualisation import plot_umap

plot_umap(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], plot_last_year_title)
# Out:
# /usr/local/lib/python3.11/dist-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")

# %%
from utlis.visualisation import plot_pca

plot_pca(k_means_outcome.iloc[:, :-1], k_means_outcome.iloc[:, -1], k_means_outcome.columns.values[:-1], plot_last_year_title)

# %%
from utlis.visualisation import plot_centroid

plot_centroid(cluster_centers, k_means_outcome, plot_last_year_title)
# Out:
# GDP deflat_0 -> GDP deflator: linked series (base year varies by country)
# Inflation,_1 -> Inflation, GDP deflator: linked series (annual %)
# Net migrat_2 -> Net migration

# %%
from utlis.map_handler import plot_map

plot_map(k_means_outcome['Cluster'], plot_last_year_title)
# Out:
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ## Dynamic Time Warping

# %%
from utlis.dtw import get_indicator_dtw_matrix, plot_time_series_compare_matrix

for indicator in df['Indicator Name'].unique():
    indicator_compare_dataframe = get_indicator_dtw_matrix(df[df['Indicator Name'] == indicator])
    plot_time_series_compare_matrix(indicator_compare_dataframe, indicator_compare_dataframe.columns, indicator, 20)

# %% [markdown]
# ## Autoencoder

# %%
from utlis.autoencoder import VAE, prepare_data, get_enoder_cluster, train
epochs = 1000

model = VAE(len(df['Indicator Name'].unique()))
X, Y = prepare_data(df)
train(model, X, epochs)
result = get_enoder_cluster(model, X, Y)
plot_map(result, "Autoencoder")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:25: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 2024-05-27 07:37:21.829571: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 18634968 exceeds 10% of free system memory.
# 2024-05-27 07:37:21.829709: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 22878720 exceeds 10% of free system memory.
# 2024-05-27 07:37:21.829788: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 22205376 exceeds 10% of free system memory.
# 2024-05-27 07:37:21.830203: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 18384300 exceeds 10% of free system memory.
# 2024-05-27 07:37:21.834193: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 18634968 exceeds 10% of free system memory.
# Epoch: 1, Test set ELBO: -9.748249053955078
# Epoch: 26, Test set ELBO: -4.23780632019043
# Epoch: 51, Test set ELBO: -2.84035062789917
# Epoch: 76, Test set ELBO: -2.509506940841675
# Epoch: 101, Test set ELBO: -2.2885828018188477
# Epoch: 126, Test set ELBO: -2.0606045722961426
# Epoch: 151, Test set ELBO: -1.991015911102295
# Epoch: 176, Test set ELBO: -1.9344398975372314
# Epoch: 201, Test set ELBO: -1.8962501287460327
# Epoch: 226, Test set ELBO: -1.9076812267303467
# Epoch: 251, Test set ELBO: -1.892643928527832
# Epoch: 276, Test set ELBO: -1.8567122220993042
# Epoch: 301, Test set ELBO: -1.8532317876815796
# Epoch: 326, Test set ELBO: -1.8323742151260376
# Epoch: 351, Test set ELBO: -1.8306221961975098
# Epoch: 376, Test set ELBO: -1.8303501605987549
# Epoch: 401, Test set ELBO: -1.8285322189331055
# Epoch: 426, Test set ELBO: -1.8105100393295288
# Epoch: 451, Test set ELBO: -1.8001892566680908
# Epoch: 476, Test set ELBO: -1.7847774028778076
# Epoch: 501, Test set ELBO: -1.7838040590286255
# Epoch: 526, Test set ELBO: -1.7818002700805664
# Epoch: 551, Test set ELBO: -1.784366250038147
# Epoch: 576, Test set ELBO: -1.7784231901168823
# Epoch: 601, Test set ELBO: -1.7701241970062256
# Epoch: 626, Test set ELBO: -1.7685644626617432
# Epoch: 651, Test set ELBO: -1.772393822669983
# Epoch: 676, Test set ELBO: -1.7660149335861206
# Epoch: 701, Test set ELBO: -1.7688183784484863
# Epoch: 726, Test set ELBO: -1.7570122480392456
# Epoch: 751, Test set ELBO: -1.7590830326080322
# Epoch: 776, Test set ELBO: -1.7432941198349
# Epoch: 801, Test set ELBO: -1.7436938285827637
# Epoch: 826, Test set ELBO: -1.7453070878982544
# Epoch: 851, Test set ELBO: -1.7453949451446533
# Epoch: 876, Test set ELBO: -1.7427270412445068
# Epoch: 901, Test set ELBO: -1.7375457286834717
# Epoch: 926, Test set ELBO: -1.7421892881393433
# Epoch: 951, Test set ELBO: -1.7304242849349976
# Epoch: 976, Test set ELBO: -1.7272908687591553
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py:1474: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (10). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# /tf/World_Bank_Data_Analysis/reports/../utlis/map_handler.py:34: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
